# %% [markdown]
# # Performing Musical Data Analysis Using Spotify

# %% [markdown]
# ## Part 1: Data pre-processing
# Before any analysis can be performed, the data must be loaded and converted to a data frame. The following code loads every song an artist has produced and places it, along with its accompanying album and audio features into a pandas dataframe. In this case Muse is used, but simply changing the artist code will allow this to work for any artist on spotify

# %%
# Libraries used
import spotipy
from spotipy.oauth2 import SpotifyClientCredentials
from spotipy.oauth2 import SpotifyOAuth
import json
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import math
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-1-7aeb0d9b2bbe> in <module>
#       1 # Libraries used
# ----> 2 import spotipy
#       3 from spotipy.oauth2 import SpotifyClientCredentials
#       4 from spotipy.oauth2 import SpotifyOAuth
#       5 import json
#
# ModuleNotFoundError: No module named 'spotipy'

# %%
# Read spotify api credentials from a file
with open('credentials.json') as f:
  data = json.load(f)

# %%
# authenticate the api
sp = spotipy.Spotify(auth_manager=SpotifyClientCredentials(client_id=data['CLIENT_ID'],
                                                          client_secret=data['CLIENT_SECRET']))

# %%
#Get Album names and URIS
artist_uri = "spotify:artist:2yEwvVSSSUkcLeSTNyHKh8"
results = sp.artist_albums(artist_uri, album_type='album')
album_names = []
album_uris = []
for i in results['items']:
    album_names.append(i['name'])
    album_uris.append(i['uri'])
album_names
# Out:
# ['Fear Inoculum', '10,000 Days', 'Lateralus', 'Ænima', 'Undertow']

# %% [markdown]
# Notice the duplicates in the albums list. In order to perform more accurate analysis, they must be removed. The following code does that.

# %%
#Remove duplicates
albums_unique = set()
for idx, val in enumerate(album_names):
    if val in albums_unique:
        album_names.pop(idx)
        album_uris.pop(idx)
    else:
        albums_unique.add(val)
print(album_names)
print(album_uris)
# Out:
# ['Fear Inoculum', '10,000 Days', 'Lateralus', 'Ænima', 'Undertow']
# ['spotify:album:7acEciVtnuTzmwKptkjth5', 'spotify:album:1fvWYcbjuycyHpzNPH1Vfk', 'spotify:album:5l5m1hnH4punS1GQXgEi3T', 'spotify:album:6yWMN087PgSimbcVmHLEwG', 'spotify:album:3Esn6LoXuWtLZNYq8FCzr0']

# %%
#Create ordered lists of songs and albums as well as a dictionary mapping song_names to uris for later use
songs = []
albums_ordered = []
dictOfSongUris = {}
for idx, val in enumerate(album_names):
    res = sp.album_tracks(album_uris[idx])
    for j in res['items']:
        songs.append(j['name'])
        albums_ordered.append(val)
        dictOfSongUris[j['name']] = j['uri']

# %%
#Extract the audio features
danceability = []
energy = []
key = []
loudness = []
mode = []
speechiness = []
acousticness = []
instrumentalness = []
liveness = []
valence = []
tempo = []
duration_ms = []
time_signature = []
for song in songs:
    #print(dictOfSongUris[song])
    features = sp.audio_features([dictOfSongUris[song]])
    danceability.append(features[0]['danceability'])
    energy.append(features[0]['energy'])
    key.append(features[0]['key'])
    loudness.append(features[0]['loudness'])
    mode.append(features[0]['mode'])
    speechiness.append(features[0]['speechiness'])
    acousticness.append(features[0]['acousticness'])
    instrumentalness.append(features[0]['instrumentalness'])
    liveness.append(features[0]['liveness'])
    valence.append(features[0]['valence'])
    tempo.append(features[0]['tempo'])
    duration_ms.append(features[0]['duration_ms'])
    time_signature.append(features[0]['time_signature'])
d = zip(songs, albums_ordered, danceability, energy, key, loudness, mode, speechiness, acousticness, instrumentalness, liveness, 
       valence, tempo, duration_ms, time_signature)

# %% [markdown]
# This code looks messy (because it is), but all it is doing is creating lists of all the audio features associated with each song. The lists are then joined together into tuples via Pythons zip() function so that a dataframe can be made.

# %%
# Build Dataframe
df = pd.DataFrame(list(d), columns=['Song Name', 'Album Name', 'Danceability', 'Energy', 'Key', 'Loudness', 'Mode', 'Speechiness',
                                   'Acousticness', 'Instrumentalness', 'Liveness', 'Valence', 'Tempo', 'Duration (MS)', 'Time Signature'])

# %%
df.head(15)
# Out:
#                    Song Name     Album Name  Danceability  Energy  Key  \
# 0              Fear Inoculum  Fear Inoculum         0.313  0.5840    7
# 1                     Pneuma  Fear Inoculum         0.417  0.5290    9
# 2     Litanie contre la Peur  Fear Inoculum         0.151  0.0137    0
# 3                 Invincible  Fear Inoculum         0.461  0.5660    9
# 4           Legion Inoculant  Fear Inoculum         0.195  0.1430    0
# 5                 Descending  Fear Inoculum         0.330  0.6100   10
# 6             Culling Voices  Fear Inoculum         0.254  0.4490   11
# 7        Chocolate Chip Trip  Fear Inoculum         0.591  0.7640    1
# 8                    7empest  Fear Inoculum         0.323  0.8030    7
# 9                Mockingbeat  Fear Inoculum         0.566  0.4460    0
# 10                 Vicarious    10,000 Days         0.506  0.8770    0
# 11                     Jambi    10,000 Days         0.475  0.8310    9
# 12    Wings For Marie (Pt 1)    10,000 Days         0.241  0.3380    2
# 13  10,000 Days (Wings Pt 2)    10,000 Days         0.259  0.6310    9
# 14                   The Pot    10,000 Days         0.469  0.7900    7
#
#     Loudness  Mode  Speechiness  Acousticness  Instrumentalness  Liveness  \
# 0    -10.091     1       0.0415      0.000824            0.5200    0.0529
# 1     -9.338     0       0.0315      0.002110            0.7550    0.1100
# 2    -22.812     0       0.0479      0.979000            0.9560    0.0869
# 3     -9.133     0       0.0566      0.009890            0.7860    0.1090
# 4    -19.052     1       0.0464      0.002290            0.9420    0.2210
# 5     -9.571     1       0.0493      0.002190            0.7690    0.1070
# 6    -12.064     0       0.0352      0.045100            0.7830    0.1390
# 7     -9.588     1       0.0465      0.034300            0.6210    0.2850
# 8     -7.397     1       0.0369      0.000073            0.8340    0.0957
# 9    -19.297     1       0.5460      0.177000            0.0006    0.0864
# 10    -5.730     1       0.0320      0.000052            0.7760    0.0712
# 11    -7.419     0       0.0505      0.000145            0.8540    0.3460
# 12   -14.484     1       0.0426      0.331000            0.8900    0.1070
# 13    -9.438     0       0.0369      0.007680            0.7740    0.1120
# 14    -6.889     1       0.0391      0.000148            0.3720    0.2820
#
#     Valence    Tempo  Duration (MS)  Time Signature
# 0    0.1590   87.894         620101               4
# 1    0.0561  114.116         713192               1
# 2    0.0371  136.297         134490               3
# 3    0.3870   88.067         764457               1
# 4    0.0262   79.539         189979               4
# 5    0.2400  172.677         817832               1
# 6    0.0386  156.094         605369               3
# 7    0.1780  128.297         288199               5
# 8    0.3860  144.755         943529               5
# 9    0.0889  115.513         125938               4
# 10   0.3020  114.589         426680               5
# 11   0.5210  110.420         448613               3
# 12   0.0362   92.517         371440               4
# 13   0.0381  123.370         673773               4
# 14   0.4660  107.450         381947               4

# %% [markdown]
# ### Adding the Banger Score
# The Banger Score is a silly attempt at quantifying how much of a "banger" a song is. Since there is no real definition, I apply my own unscientific equation (see "Util Functions")

# %%
#Convert to numpy arrays
energy = df['Energy'].to_numpy()
loudness = df['Loudness'].to_numpy()
tempo = df['Tempo'].to_numpy()
acousticness = df['Acousticness'].to_numpy()
bs = banger_score(energy, loudness, tempo, acousticness)
df['Banger Score'] = bs
# Out:
# E:\Program Files\Anaconda\lib\site-packages\ipykernel_launcher.py:2: RuntimeWarning: invalid value encountered in log

# %%
# Write the dataframe to a csv file
df.to_csv('muse_features.csv')

# %% [markdown]
# ## Part 2: Data Analysis

# %% [markdown]
# TODO

# %%
df.describe()
# Out:
#        Danceability    Energy        Key   Loudness       Mode  Speechiness  \
# count     59.000000  59.00000  59.000000  59.000000  59.000000    59.000000
# mean       0.386864   0.56812   5.593220 -12.796373   0.644068     0.097015
# std        0.131228   0.26433   3.686502   7.565978   0.482905     0.136255
# min        0.106000   0.01120   0.000000 -36.756000   0.000000     0.029300
# 25%        0.313500   0.43400   2.000000 -16.812500   0.000000     0.037000
# 50%        0.371000   0.63100   7.000000  -9.338000   1.000000     0.046500
# 75%        0.465000   0.77200   9.000000  -7.492500   1.000000     0.072050
# max        0.747000   0.97100  11.000000  -5.730000   1.000000     0.691000
#
#        Acousticness  Instrumentalness   Liveness    Valence       Tempo  \
# count     59.000000         59.000000  59.000000  59.000000   59.000000
# mean       0.152109          0.616413   0.167078   0.258992  118.820000
# std        0.303866          0.286792   0.144090   0.193667   29.993372
# min        0.000011          0.000006   0.028400   0.022700   59.378000
# 25%        0.000179          0.455000   0.091350   0.082300   97.561500
# 50%        0.002110          0.755000   0.111000   0.240000  114.116000
# 75%        0.102000          0.838500   0.172500   0.387500  137.864000
# max        0.991000          0.994000   0.914000   0.953000  187.599000
#
#        Duration (MS)  Time Signature  Banger Score
# count      59.000000       59.000000     59.000000
# mean   391366.474576        3.542373      0.640386
# std    224060.850076        1.071931      0.342139
# min     38760.000000        1.000000      0.000500
# 25%    257200.000000        3.000000      0.361343
# 50%    363680.000000        4.000000      0.801296
# 75%    510113.500000        4.000000      0.907282
# max    947002.000000        5.000000      0.968001

# %%
# Extract mean values by album and drop categorical variables
temp_album_names = album_names
temp_album_names.reverse()
mean_vals = df.groupby(['Album Name']).mean()
mean_vals = mean_vals.drop(['Key','Mode', 'Time Signature'], axis=1)
mean_vals = mean_vals.reindex(temp_album_names)
mean_vals
# Out:
#                Danceability    Energy   Loudness  Speechiness  Acousticness  \
# Album Name
# Undertow           0.419300  0.703900  -8.781100     0.088460      0.021788
# Ænima              0.409600  0.556240 -14.044067     0.169160      0.194902
# Lateralus          0.369692  0.549908 -14.463077     0.054646      0.144813
# 10,000 Days        0.371000  0.552727 -12.741000     0.059427      0.245245
# Fear Inoculum      0.360100  0.490770 -12.834300     0.093780      0.125278
#
#                Instrumentalness  Liveness   Valence       Tempo  \
# Album Name
# Undertow               0.421670  0.154490  0.295430  129.205100
# Ænima                  0.579927  0.157267  0.329260  128.732600
# Lateralus              0.673861  0.209538  0.251015  108.977308
# 10,000 Days            0.702364  0.176073  0.229745  104.307818
# Fear Inoculum          0.696660  0.129290  0.159690  122.324900
#
#                Duration (MS)  Banger Score
# Album Name
# Undertow       409305.500000      0.831742
# Ænima          309612.533333      0.658326
# Lateralus      353793.846154      0.585117
# 10,000 Days    413724.818182      0.508180
# Fear Inoculum  520308.600000      0.639397

# %%
plt.figure(figsize=(12,6))
ax = sns.barplot(x=mean_vals.index, y='Banger Score', data=mean_vals)
ax.set_xticklabels(ax.get_xticklabels(), rotation=40, ha='right')
# Out:
# [Text(0, 0, 'Undertow'),
#  Text(0, 0, 'Ænima'),
#  Text(0, 0, 'Lateralus'),
#  Text(0, 0, '10,000 Days'),
#  Text(0, 0, 'Fear Inoculum')]

# %%
df
# Out:
#                    Song Name     Album Name  Danceability  Energy  Key  \
# 0              Fear Inoculum  Fear Inoculum         0.313  0.5840    7
# 1                     Pneuma  Fear Inoculum         0.417  0.5290    9
# 2     Litanie contre la Peur  Fear Inoculum         0.151  0.0137    0
# 3                 Invincible  Fear Inoculum         0.461  0.5660    9
# 4           Legion Inoculant  Fear Inoculum         0.195  0.1430    0
# 5                 Descending  Fear Inoculum         0.330  0.6100   10
# 6             Culling Voices  Fear Inoculum         0.254  0.4490   11
# 7        Chocolate Chip Trip  Fear Inoculum         0.591  0.7640    1
# 8                    7empest  Fear Inoculum         0.323  0.8030    7
# 9                Mockingbeat  Fear Inoculum         0.566  0.4460    0
# 10                 Vicarious    10,000 Days         0.506  0.8770    0
# 11                     Jambi    10,000 Days         0.475  0.8310    9
# 12    Wings For Marie (Pt 1)    10,000 Days         0.241  0.3380    2
# 13  10,000 Days (Wings Pt 2)    10,000 Days         0.259  0.6310    9
# 14                   The Pot    10,000 Days         0.469  0.7900    7
# 15           Lipan Conjuring    10,000 Days         0.307  0.0480    8
# 16  Lost Keys (Blame Hofman)    10,000 Days         0.281  0.3850    7
# 17            Rosetta Stoned    10,000 Days         0.381  0.8200    7
# 18                 Intension    10,000 Days         0.603  0.4220    7
# 19              Right In Two    10,000 Days         0.440  0.5680    7
# 20              Viginti Tres    10,000 Days         0.119  0.3700    9
# 21                The Grudge      Lateralus         0.456  0.7950    2
# 22       Eon Blue Apocalypse      Lateralus         0.106  0.0449    2
# 23               The Patient      Lateralus         0.457  0.5240    9
# 24                    Mantra      Lateralus         0.260  0.0112    0
# 25                    Schism      Lateralus         0.567  0.7140    9
# 26                   Parabol      Lateralus         0.355  0.0497    4
# 27                  Parabola      Lateralus         0.314  0.9300    9
# 28           Ticks & Leeches      Lateralus         0.344  0.7170    9
# 29                 Lateralus      Lateralus         0.387  0.6780    0
# 30               Disposition      Lateralus         0.683  0.2280    9
# 31                Reflection      Lateralus         0.357  0.6620    7
# 32                     Triad      Lateralus         0.284  0.8240    9
# 33             Faaip De Oiad      Lateralus         0.236  0.9710    6
# 34                 Stinkfist          Ænima         0.286  0.7280    0
# 35                    Eulogy          Ænima         0.517  0.6460    4
# 36                        H.          Ænima         0.553  0.4710    2
# 37              Useful Idiot          Ænima         0.371  0.4880   10
# 38             Forty Six & 2          Ænima         0.375  0.6820    0
# 39  Message To Harry Manback          Ænima         0.404  0.1160    4
# 40       Hooker With A Penis          Ænima         0.317  0.9110    7
# 41              Intermission          Ænima         0.484  0.0136    7
# 42                     Jimmy          Ænima         0.477  0.6880    7
# 43        Die Eier von Satan          Ænima         0.747  0.5880    1
# 44                    Pushit          Ænima         0.354  0.6250    7
# 45        Cesaro Summability          Ænima         0.342  0.3430   11
# 46                     Ænema          Ænima         0.335  0.8490    0
# 47                  (-) Ions          Ænima         0.223  0.5670    9
# 48                 Third Eye          Ænima         0.359  0.6280    7
# 49               Intolerance       Undertow         0.412  0.9420    7
# 50                Prison Sex       Undertow         0.490  0.7800   11
# 51                     Sober       Undertow         0.385  0.6730    2
# 52                    Bottom       Undertow         0.373  0.6980    2
# 53                Crawl Away       Undertow         0.346  0.7930   11
# 54                Swamp Song       Undertow         0.639  0.6810    2
# 55                  Undertow       Undertow         0.359  0.7970    2
# 56                        4°       Undertow         0.427  0.7140    9
# 57                     Flood       Undertow         0.421  0.6910    2
# 58             Disgustipated       Undertow         0.341  0.2700    5
#
#     Loudness  Mode  Speechiness  Acousticness  Instrumentalness  Liveness  \
# 0    -10.091     1       0.0415      0.000824          0.520000    0.0529
# 1     -9.338     0       0.0315      0.002110          0.755000    0.1100
# 2    -22.812     0       0.0479      0.979000          0.956000    0.0869
# 3     -9.133     0       0.0566      0.009890          0.786000    0.1090
# 4    -19.052     1       0.0464      0.002290          0.942000    0.2210
# 5     -9.571     1       0.0493      0.002190          0.769000    0.1070
# 6    -12.064     0       0.0352      0.045100          0.783000    0.1390
# 7     -9.588     1       0.0465      0.034300          0.621000    0.2850
# 8     -7.397     1       0.0369      0.000073          0.834000    0.0957
# 9    -19.297     1       0.5460      0.177000          0.000600    0.0864
# 10    -5.730     1       0.0320      0.000052          0.776000    0.0712
# 11    -7.419     0       0.0505      0.000145          0.854000    0.3460
# 12   -14.484     1       0.0426      0.331000          0.890000    0.1070
# 13    -9.438     0       0.0369      0.007680          0.774000    0.1120
# 14    -6.889     1       0.0391      0.000148          0.372000    0.2820
# 15   -25.331     0       0.0751      0.958000          0.000006    0.0899
# 16   -15.219     1       0.0403      0.274000          0.882000    0.5100
# 17    -6.418     0       0.0398      0.000249          0.725000    0.1520
# 18   -15.598     1       0.0631      0.281000          0.776000    0.0745
# 19    -8.540     1       0.0293      0.004420          0.840000    0.1190
# 20   -25.085     1       0.2050      0.841000          0.837000    0.0732
# 21    -7.408     1       0.0363      0.000159          0.842000    0.2690
# 22   -26.389     1       0.0382      0.143000          0.845000    0.4130
# 23    -9.774     0       0.0334      0.001520          0.759000    0.1020
# 24   -36.756     0       0.0317      0.799000          0.994000    0.1000
# 25    -8.512     0       0.0302      0.001200          0.420000    0.1860
# 26   -24.949     1       0.0412      0.544000          0.301000    0.0897
# 27    -6.237     1       0.1050      0.000020          0.501000    0.1390
# 28    -9.427     1       0.0637      0.000094          0.794000    0.0663
# 29    -8.399     1       0.0817      0.001080          0.872000    0.1010
# 30   -18.027     1       0.0451      0.061000          0.845000    0.1140
# 31   -10.257     1       0.0406      0.003490          0.742000    0.1050
# 32    -9.289     0       0.0593      0.000011          0.844000    0.1250
# 33   -12.596     1       0.1040      0.328000          0.001190    0.9140
# 34    -6.608     1       0.0616      0.000174          0.837000    0.1330
# 35    -9.059     0       0.1370      0.005560          0.783000    0.0985
# 36    -9.776     0       0.0371      0.022200          0.601000    0.1250
# 37   -24.646     0       0.6910      0.000012          0.532000    0.4450
# 38    -6.901     0       0.0364      0.001550          0.600000    0.0897
# 39   -32.727     0       0.0443      0.991000          0.867000    0.1040
# 40    -7.363     1       0.1770      0.001280          0.555000    0.1480
# 41   -26.645     0       0.0603      0.929000          0.931000    0.2950
# 42    -8.256     0       0.0373      0.007460          0.211000    0.1310
# 43    -7.412     1       0.0733      0.018200          0.012900    0.1000
# 44    -8.437     1       0.0359      0.000510          0.569000    0.0798
# 45   -21.736     0       0.1910      0.000799          0.779000    0.0832
# 46    -6.927     1       0.3190      0.001930          0.256000    0.0928
# 47   -24.483     1       0.5800      0.938000          0.693000    0.3230
# 48    -9.685     1       0.0562      0.005850          0.472000    0.1110
# 49    -7.566     1       0.0708      0.000013          0.286000    0.1590
# 50    -8.535     0       0.1310      0.000288          0.019700    0.1080
# 51    -8.182     1       0.0329      0.000183          0.150000    0.0699
# 52    -7.278     1       0.0348      0.000056          0.891000    0.1260
# 53    -7.990     1       0.0412      0.000017          0.438000    0.3930
# 54    -6.735     1       0.0334      0.000698          0.198000    0.1190
# 55    -6.623     1       0.0537      0.000080          0.805000    0.2780
# 56    -7.967     1       0.0520      0.000376          0.664000    0.1870
# 57    -7.982     1       0.0558      0.000166          0.604000    0.0284
# 58   -18.953     1       0.3790      0.216000          0.161000    0.0766
#
#     Valence    Tempo  Duration (MS)  Time Signature  Banger Score
# 0    0.1590   87.894         620101               4      0.721761
# 1    0.0561  114.116         713192               1      0.713843
# 2    0.0371  136.297         134490               3      0.001449
# 3    0.3870   88.067         764457               1      0.722661
# 4    0.0262   79.539         189979               4      0.400075
# 5    0.2400  172.677         817832               1      0.922660
# 6    0.0386  156.094         605369               3      0.820157
# 7    0.1780  128.297         288199               5      0.878164
# 8    0.3860  144.755         943529               5      0.949875
# 9    0.0889  115.513         125938               4      0.263320
# 10   0.3020  114.589         426680               5      0.908781
# 11   0.5210  110.420         448613               3      0.859226
# 12   0.0362   92.517         371440               4      0.104277
# 13   0.0381  123.370         673773               4      0.840248
# 14   0.4660  107.450         381947               4      0.861828
# 15   0.1840   74.329          71053               1      0.000602
# 16   0.0618  122.115         226267               4      0.229410
# 17   0.5740  111.820         671360               4      0.880416
# 18   0.0685   95.170         441253               1      0.156845
# 19   0.2480  118.389         535800               3      0.745740
# 20   0.0276   77.217         302787               4      0.002603
# 21   0.3090   96.045         515080               5      0.850532
# 22   0.0699  146.711          64293               3      0.372057
# 23   0.3890  110.711         433920               5      0.702761
# 24   0.0379   80.305          72680               3      0.001503
# 25   0.1910  107.438         403533               3      0.801296
# 26   0.0757   79.872         184573               4      0.010903
# 27   0.2940  100.935         363680               4      0.905783
# 28   0.2750   99.078         487547               4      0.784844
# 29   0.3680  172.641         562707               3      0.940943
# 30   0.1930  117.173         286267               5      0.350629
# 31   0.5590   90.386         667960               4      0.745454
# 32   0.4790  106.370         395907               3      0.821195
# 33   0.0227  109.040         161173               5      0.318625
# 34   0.4670  171.454         312120               4      0.960455
# 35   0.3610  165.653         505147               4      0.926878
# 36   0.0908  100.322         367133               4      0.647830
# 37   0.1060  187.599          38760               4      0.844631
# 38   0.3910  159.231         363067               4      0.949574
# 39   0.5240   90.580         113227               3      0.000500
# 40   0.2740  123.254         273827               4      0.927875
# 41   0.9530   59.378          56000               3      0.000675
# 42   0.4550  126.291         324427               3      0.890726
# 43   0.3980   94.095         137360               3      0.768127
# 44   0.1750  119.583         595613               3      0.759798
# 45   0.1960  115.350          86227               4      0.485123
# 46   0.2560  181.701         399267               3      0.968001
# 47   0.0301  127.091         240573               4      0.004383
# 48   0.2620  109.407         831440               4      0.740309
# 49   0.2110  101.892         294027               4      0.881385
# 50   0.3880  108.138         296320               4      0.821952
# 51   0.1870  149.272         306853               4      0.931200
# 52   0.2780  139.431         433813               4      0.935639
# 53   0.6530  155.946         330427               4      0.949899
# 54   0.3710  129.098         331853               3      0.925102
# 55   0.4730  171.526         322017               3      0.965298
# 56   0.2390  113.603         362890               5      0.814655
# 57   0.1190  142.900         467853               1      0.930418
# 58   0.0353   80.245         947002               4      0.161870

# %% [markdown]
# ## Util Functions

# %%
def banger_score(energy, loudness, tempo, acousticness):
    return sigmoid(2*energy + tempo_adjust(tempo) + loudness_adjust(loudness) - 7*acousticness)
                   
# Energy: [0,1] Loudness: [-60,0] Tempo [0,inf] acousticness [0,1]

# %%
def loudness_adjust(loudness):
    adjust = (1/(-loudness/10)) - 1.2
    adjust[adjust > 1] = 1
    return adjust

# %%
def tempo_adjust(tempo):
    a =  0.1 + np.log(tempo - 119)/np.log(20)
    return np.nan_to_num(a, nan=0)

# %%
def sigmoid(z):
    return 1 / (1+np.exp(-z))
